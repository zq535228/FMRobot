# %%
from selenium import webdriver
import requests
import json,re
import pprint
from selenium.webdriver.chrome.options import Options

# hide browser window
chrome_options = Options()
chrome_options.add_argument("--headless")       # define headless

# add the option when creating driver
driver = webdriver.Chrome(chrome_options=chrome_options)

driver.get("https://auth.followme.com/login?source=iframe")
driver.find_element_by_xpath(u"(.//*[normalize-space(text()) and normalize-space(.)='验证码登录'])[1]/following::button[1]").click()
driver.find_element_by_xpath(u"(.//*[normalize-space(text()) and normalize-space(.)='注册'])[1]/following::input[1]").clear()
driver.find_element_by_xpath(u"(.//*[normalize-space(text()) and normalize-space(.)='注册'])[1]/following::input[1]").send_keys("13604023002")
driver.find_element_by_xpath(u"(.//*[normalize-space(text()) and normalize-space(.)='注册'])[1]/following::input[2]").clear()
driver.find_element_by_xpath(u"(.//*[normalize-space(text()) and normalize-space(.)='注册'])[1]/following::input[2]").send_keys("z123456")
driver.find_element_by_id("login-password").click()

driver.get("https://www.followme.com/?t=my")

html = driver.page_source

if "与世界分享" in html:
    print('login in success')

url  = "https://www.followme.com/api/v2/trade/traders/230764_2/followers?isFollowing=false&pageSize=20&pageIndex=1&accountType=&pageField=PROFIT&pageSort=DESC&flag=1"

driver.get(url)
html = driver.page_source
html = re.sub(r'<.*?>','',html)

j1 = json.loads(html)

 
pprint.pprint(j1)
# Out:
# c:\program files (x86)\python37-32\lib\site-packages\ipykernel_launcher.py:12: DeprecationWarning: use options instead of chrome_options
#   if sys.path[0] == '':
# login in success
# {'code': 0,
#  'data': {'brokers': [{'BrokerId': 1000652, 'BrokerName': 'TradeMax'}],
#           'items': [{'AccountCurrentIndex': 1,
#                      'AccountCurrentIndexPad': '01',
#                      'AccountList': [{'AccountIndex': 1,
#                                       'AccountIndexPad': '01',
#                                       'AccountType': 0,
#                                       'BrokerId': 3,
#                                       'BrokerName': '模拟账户',
#                                       'UserType': 0}],
#                      'BizEndDate': '2019/01/01 02:30:01',
#                      'BizFollowAmount': '10,132.28',
#                      'BizFollowVolume': '0.00',
#                      'BizOneDayProfit': '0.00',
#                      'BizProfit': '132.28',
#                      'BizStartDate': '2018/12/25 20:12:33',
#                      'BizStrategyType': '固定数量',
#                      'BizWeeks': 1,
#                      'Chart': [{'Date': 20181226,
#                                 'FollowerTotalProfit': 42.8,
#                                 'TraderTotalProfit': 58.1},
#                                {'Date': 20181227,
#                                 'FollowerTotalProfit': 98.59,
#                                 'TraderTotalProfit': 177.2},
#                                {'Date': 20181228,
#                                 'FollowerTotalProfit': 123.71,
#                                 'TraderTotalProfit': 267.87},
#                                {'Date': 20181230,
#                                 'FollowerTotalProfit': 123.71,
#                                 'TraderTotalProfit': 267.87},
#                                {'Date': 20181231,
#                                 'FollowerTotalProfit': 128.81,
#                                 'TraderTotalProfit': 337.31}],
#                      'CustomerNickName': '大太阳37',
#                      'CustomerUserId': 231495,
#                      'Direction': 1,
#                      'EndDate': '2019-01-01 02:30:01',
#                      'FollowBrokerID': 3,
#                      'FollowList': [{'Date': '1545753600',
#                                      'FollowMoney': 42.800000000000004,
#                                      'Money': 42.800000000000004,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 42.800000000000004,
#                                      'TotalPips': 0,
#                                      'TotalSelfMoney': 0,
#                                      'TotalSelfPips': 0,
#                                      'TotalSelfStandardlots': 0,
#                                      'TotalStandardlots': 0},
#                                     {'Date': '1545840000',
#                                      'FollowMoney': 55.789999999999985,
#                                      'Money': 55.789999999999985,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 98.58999999999999,
#                                      'TotalPips': 0,
#                                      'TotalSelfMoney': 0,
#                                      'TotalSelfPips': 0,
#                                      'TotalSelfStandardlots': 0,
#                                      'TotalStandardlots': 0},
#                                     {'Date': '1545926400',
#                                      'FollowMoney': 25.120000000000005,
#                                      'Money': 25.120000000000005,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 123.71,
#                                      'TotalPips': 0,
#                                      'TotalSelfMoney': 0,
#                                      'TotalSelfPips': 0,
#                                      'TotalSelfStandardlots': 0,
#                                      'TotalStandardlots': 0},
#                                     {'Date': '1546185600',
#                                      'FollowMoney': 5.1000000000000005,
#                                      'Money': 5.1000000000000005,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 128.81,
#                                      'TotalPips': 0,
#                                      'TotalSelfMoney': 0,
#                                      'TotalSelfPips': 0,
#                                      'TotalSelfStandardlots': 0,
#                                      'TotalStandardlots': 0}],
#                      'FollowSetting': '0.01',
#                      'LastFollow': '',
#                      'MaxProfit': 9.88,
#                      'MinProfit': -10.16,
#                      'Profit': 132.27999999999997,
#                      'StandardLots': 1.8000000000000014,
#                      'StartDate': '2018-12-25 20:12:33',
#                      'StrategyType': 1,
#                      'TotalDays': 7,
#                      'TotalTrades': 180,
#                      'TraderList': [{'Date': '1545667200',
#                                      'FollowMoney': 0,
#                                      'Money': 11.469999999999999,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 11205.999999999996,
#                                      'TotalPips': 16081.099999999997,
#                                      'TotalSelfMoney': 11205.999999999996,
#                                      'TotalSelfPips': 16081.099999999997,
#                                      'TotalSelfStandardlots': 90.92000000000003,
#                                      'TotalStandardlots': 90.92000000000003},
#                                     {'Date': '1545753600',
#                                      'FollowMoney': 0,
#                                      'Money': 58.100000000000016,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 11264.099999999997,
#                                      'TotalPips': 16258.199999999997,
#                                      'TotalSelfMoney': 11264.099999999997,
#                                      'TotalSelfPips': 16258.199999999997,
#                                      'TotalSelfStandardlots': 91.56000000000003,
#                                      'TotalStandardlots': 91.56000000000003},
#                                     {'Date': '1545840000',
#                                      'FollowMoney': 0,
#                                      'Money': 119.09999999999997,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 11383.199999999997,
#                                      'TotalPips': 16715.799999999996,
#                                      'TotalSelfMoney': 11383.199999999997,
#                                      'TotalSelfPips': 16715.799999999996,
#                                      'TotalSelfStandardlots': 92.64000000000003,
#                                      'TotalStandardlots': 92.64000000000003},
#                                     {'Date': '1545926400',
#                                      'FollowMoney': 0,
#                                      'Money': 90.66999999999997,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 11473.869999999997,
#                                      'TotalPips': 17263.099999999995,
#                                      'TotalSelfMoney': 11473.869999999997,
#                                      'TotalSelfPips': 17263.099999999995,
#                                      'TotalSelfStandardlots': 93.39000000000003,
#                                      'TotalStandardlots': 93.39000000000003},
#                                     {'Date': '1546012800',
#                                      'FollowMoney': 0,
#                                      'Money': 7.9,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 11481.769999999997,
#                                      'TotalPips': 17319.799999999996,
#                                      'TotalSelfMoney': 11481.769999999997,
#                                      'TotalSelfPips': 17319.799999999996,
#                                      'TotalSelfStandardlots': 93.43000000000004,
#                                      'TotalStandardlots': 93.43000000000004},
#                                     {'Date': '1546099200',
#                                      'FollowMoney': 0,
#                                      'Money': 0,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 11481.769999999997,
#                                      'TotalPips': 17319.799999999996,
#                                      'TotalSelfMoney': 11481.769999999997,
#                                      'TotalSelfPips': 17319.799999999996,
#                                      'TotalSelfStandardlots': 93.43000000000004,
#                                      'TotalStandardlots': 93.43000000000004},
#                                     {'Date': '1546185600',
#                                      'FollowMoney': 0,
#                                      'Money': 69.43999999999998,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 11551.209999999997,
#                                      'TotalPips': 17350.399999999994,
#                                      'TotalSelfMoney': 11551.209999999997,
#                                      'TotalSelfPips': 17350.399999999994,
#                                      'TotalSelfStandardlots': 94.24000000000004,
#                                      'TotalStandardlots': 94.24000000000004},
#                                     {'Date': '1546272000',
#                                      'FollowMoney': 0,
#                                      'Money': 11.16,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 11562.369999999997,
#                                      'TotalPips': 17474.699999999993,
#                                      'TotalSelfMoney': 11562.369999999997,
#                                      'TotalSelfPips': 17474.699999999993,
#                                      'TotalSelfStandardlots': 94.28000000000004,
#                                      'TotalStandardlots': 94.28000000000004}]},
#                     {'AccountCurrentIndex': 1,
#                      'AccountCurrentIndexPad': '01',
#                      'AccountList': [{'AccountIndex': 1,
#                                       'AccountIndexPad': '01',
#                                       'AccountType': 0,
#                                       'BrokerId': 3,
#                                       'BrokerName': '模拟账户',
#                                       'UserType': 0}],
#                      'BizEndDate': '2018/12/31 08:48:10',
#                      'BizFollowAmount': '10,106.27',
#                      'BizFollowVolume': '0.00',
#                      'BizOneDayProfit': '0.00',
#                      'BizProfit': '106.27',
#                      'BizStartDate': '2018/12/26 20:56:16',
#                      'BizStrategyType': '固定数量',
#                      'BizWeeks': 1,
#                      'Chart': [{'Date': 20181226,
#                                 'FollowerTotalProfit': 18.01,
#                                 'TraderTotalProfit': 58.1},
#                                {'Date': 20181227,
#                                 'FollowerTotalProfit': 76.41,
#                                 'TraderTotalProfit': 177.2},
#                                {'Date': 20181228,
#                                 'FollowerTotalProfit': 104.3,
#                                 'TraderTotalProfit': 267.87},
#                                {'Date': 20181230,
#                                 'FollowerTotalProfit': 104.3,
#                                 'TraderTotalProfit': 267.87},
#                                {'Date': 20181231,
#                                 'FollowerTotalProfit': 106.27,
#                                 'TraderTotalProfit': 337.31}],
#                      'CustomerNickName': '晓米团子',
#                      'CustomerUserId': 225134,
#                      'Direction': 1,
#                      'EndDate': '2018-12-31 08:48:10',
#                      'FollowBrokerID': 3,
#                      'FollowList': [{'Date': '1545840000',
#                                      'FollowMoney': 58.400000000000006,
#                                      'Money': 58.400000000000006,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 58.400000000000006,
#                                      'TotalPips': 0,
#                                      'TotalSelfMoney': 0,
#                                      'TotalSelfPips': 0,
#                                      'TotalSelfStandardlots': 0,
#                                      'TotalStandardlots': 0},
#                                     {'Date': '1545926400',
#                                      'FollowMoney': 27.89,
#                                      'Money': 27.89,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 86.29,
#                                      'TotalPips': 0,
#                                      'TotalSelfMoney': 0,
#                                      'TotalSelfPips': 0,
#                                      'TotalSelfStandardlots': 0,
#                                      'TotalStandardlots': 0}],
#                      'FollowSetting': '0.01',
#                      'LastFollow': '',
#                      'MaxProfit': 6.2,
#                      'MinProfit': -4.62,
#                      'Profit': 106.26999999999998,
#                      'StandardLots': 1.0300000000000007,
#                      'StartDate': '2018-12-26 20:56:16',
#                      'StrategyType': 1,
#                      'TotalDays': 5,
#                      'TotalTrades': 103,
#                      'TraderList': [{'Date': '1545753600',
#                                      'FollowMoney': 0,
#                                      'Money': 58.100000000000016,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 11264.099999999997,
#                                      'TotalPips': 16258.199999999997,
#                                      'TotalSelfMoney': 11264.099999999997,
#                                      'TotalSelfPips': 16258.199999999997,
#                                      'TotalSelfStandardlots': 91.56000000000003,
#                                      'TotalStandardlots': 91.56000000000003},
#                                     {'Date': '1545840000',
#                                      'FollowMoney': 0,
#                                      'Money': 119.09999999999997,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 11383.199999999997,
#                                      'TotalPips': 16715.799999999996,
#                                      'TotalSelfMoney': 11383.199999999997,
#                                      'TotalSelfPips': 16715.799999999996,
#                                      'TotalSelfStandardlots': 92.64000000000003,
#                                      'TotalStandardlots': 92.64000000000003},
#                                     {'Date': '1545926400',
#                                      'FollowMoney': 0,
#                                      'Money': 90.66999999999997,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 11473.869999999997,
#                                      'TotalPips': 17263.099999999995,
#                                      'TotalSelfMoney': 11473.869999999997,
#                                      'TotalSelfPips': 17263.099999999995,
#                                      'TotalSelfStandardlots': 93.39000000000003,
#                                      'TotalStandardlots': 93.39000000000003},
#                                     {'Date': '1546012800',
#                                      'FollowMoney': 0,
#                                      'Money': 7.9,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 11481.769999999997,
#                                      'TotalPips': 17319.799999999996,
#                                      'TotalSelfMoney': 11481.769999999997,
#                                      'TotalSelfPips': 17319.799999999996,
#                                      'TotalSelfStandardlots': 93.43000000000004,
#                                      'TotalStandardlots': 93.43000000000004},
#                                     {'Date': '1546099200',
#                                      'FollowMoney': 0,
#                                      'Money': 0,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 11481.769999999997,
#                                      'TotalPips': 17319.799999999996,
#                                      'TotalSelfMoney': 11481.769999999997,
#                                      'TotalSelfPips': 17319.799999999996,
#                                      'TotalSelfStandardlots': 93.43000000000004,
#                                      'TotalStandardlots': 93.43000000000004},
#                                     {'Date': '1546185600',
#                                      'FollowMoney': 0,
#                                      'Money': 69.43999999999998,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 11551.209999999997,
#                                      'TotalPips': 17350.399999999994,
#                                      'TotalSelfMoney': 11551.209999999997,
#                                      'TotalSelfPips': 17350.399999999994,
#                                      'TotalSelfStandardlots': 94.24000000000004,
#                                      'TotalStandardlots': 94.24000000000004}]},
#                     {'AccountCurrentIndex': 1,
#                      'AccountCurrentIndexPad': '01',
#                      'AccountList': [{'AccountIndex': 1,
#                                       'AccountIndexPad': '01',
#                                       'AccountType': 0,
#                                       'BrokerId': 3,
#                                       'BrokerName': '模拟账户',
#                                       'UserType': 0}],
#                      'BizEndDate': '2018/12/28 14:43:44',
#                      'BizFollowAmount': '10,056.74',
#                      'BizFollowVolume': '0.00',
#                      'BizOneDayProfit': '0.00',
#                      'BizProfit': '56.74',
#                      'BizStartDate': '2018/12/27 11:30:59',
#                      'BizStrategyType': '固定数量',
#                      'BizWeeks': 1,
#                      'Chart': [{'Date': 20181227,
#                                 'FollowerTotalProfit': 47.41,
#                                 'TraderTotalProfit': 119.1},
#                                {'Date': 20181228,
#                                 'FollowerTotalProfit': 60.72,
#                                 'TraderTotalProfit': 209.77},
#                                {'Date': 20181230,
#                                 'FollowerTotalProfit': 60.72,
#                                 'TraderTotalProfit': 209.77},
#                                {'Date': 20181231,
#                                 'FollowerTotalProfit': 56.74,
#                                 'TraderTotalProfit': 279.21}],
#                      'CustomerNickName': '李书函',
#                      'CustomerUserId': 231839,
#                      'Direction': 1,
#                      'EndDate': '2018-12-28 14:43:44',
#                      'FollowBrokerID': 3,
#                      'FollowList': [],
#                      'FollowSetting': '0.01',
#                      'LastFollow': '',
#                      'MaxProfit': 5.76,
#                      'MinProfit': -4.92,
#                      'Profit': 56.740000000000016,
#                      'StandardLots': 0.6000000000000003,
#                      'StartDate': '2018-12-27 11:30:59',
#                      'StrategyType': 1,
#                      'TotalDays': 1,
#                      'TotalTrades': 60,
#                      'TraderList': [{'Date': '1545840000',
#                                      'FollowMoney': 0,
#                                      'Money': 119.09999999999997,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 11383.199999999997,
#                                      'TotalPips': 16715.799999999996,
#                                      'TotalSelfMoney': 11383.199999999997,
#                                      'TotalSelfPips': 16715.799999999996,
#                                      'TotalSelfStandardlots': 92.64000000000003,
#                                      'TotalStandardlots': 92.64000000000003},
#                                     {'Date': '1545926400',
#                                      'FollowMoney': 0,
#                                      'Money': 90.66999999999997,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 11473.869999999997,
#                                      'TotalPips': 17263.099999999995,
#                                      'TotalSelfMoney': 11473.869999999997,
#                                      'TotalSelfPips': 17263.099999999995,
#                                      'TotalSelfStandardlots': 93.39000000000003,
#                                      'TotalStandardlots': 93.39000000000003}]},
#                     {'AccountCurrentIndex': 1,
#                      'AccountCurrentIndexPad': '01',
#                      'AccountList': [{'AccountIndex': 1,
#                                       'AccountIndexPad': '01',
#                                       'AccountType': 0,
#                                       'BrokerId': 3,
#                                       'BrokerName': '模拟账户',
#                                       'UserType': 0},
#                                      {'AccountIndex': 2,
#                                       'AccountIndexPad': '02',
#                                       'AccountType': 2,
#                                       'BrokerId': 1001482,
#                                       'BrokerName': 'Rubix FX格伦外汇',
#                                       'UserType': 2},
#                                      {'AccountIndex': 3,
#                                       'AccountIndexPad': '03',
#                                       'AccountType': 2,
#                                       'BrokerId': 1001482,
#                                       'BrokerName': 'Rubix FX格伦外汇',
#                                       'UserType': 2}],
#                      'BizEndDate': '2018/12/30 21:22:03',
#                      'BizFollowAmount': '10,001.99',
#                      'BizFollowVolume': '0.00',
#                      'BizOneDayProfit': '0.00',
#                      'BizProfit': '0.00',
#                      'BizStartDate': '2018/12/29 21:14:25',
#                      'BizStrategyType': '按比例',
#                      'BizWeeks': 1,
#                      'Chart': [],
#                      'CustomerNickName': 'dilhush操盘手',
#                      'CustomerUserId': 232066,
#                      'Direction': 1,
#                      'EndDate': '2018-12-30 21:22:03',
#                      'FollowBrokerID': 3,
#                      'FollowList': [],
#                      'FollowSetting': '0.5',
#                      'LastFollow': '',
#                      'MaxProfit': 0,
#                      'MinProfit': 0,
#                      'Profit': 0,
#                      'StandardLots': 0,
#                      'StartDate': '2018-12-29 21:14:25',
#                      'StrategyType': 2,
#                      'TotalDays': 1,
#                      'TotalTrades': 0,
#                      'TraderList': [{'Date': '1546012800',
#                                      'FollowMoney': 0,
#                                      'Money': 7.9,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 11481.769999999997,
#                                      'TotalPips': 17319.799999999996,
#                                      'TotalSelfMoney': 11481.769999999997,
#                                      'TotalSelfPips': 17319.799999999996,
#                                      'TotalSelfStandardlots': 93.43000000000004,
#                                      'TotalStandardlots': 93.43000000000004},
#                                     {'Date': '1546099200',
#                                      'FollowMoney': 0,
#                                      'Money': 0,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 11481.769999999997,
#                                      'TotalPips': 17319.799999999996,
#                                      'TotalSelfMoney': 11481.769999999997,
#                                      'TotalSelfPips': 17319.799999999996,
#                                      'TotalSelfStandardlots': 93.43000000000004,
#                                      'TotalStandardlots': 93.43000000000004}]},
#                     {'AccountCurrentIndex': 3,
#                      'AccountCurrentIndexPad': '03',
#                      'AccountList': [{'AccountIndex': 1,
#                                       'AccountIndexPad': '01',
#                                       'AccountType': 0,
#                                       'BrokerId': 3,
#                                       'BrokerName': '模拟账户',
#                                       'UserType': 0},
#                                      {'AccountIndex': 2,
#                                       'AccountIndexPad': '02',
#                                       'AccountType': 1,
#                                       'BrokerId': 6,
#                                       'BrokerName': 'KVB昆仑国际',
#                                       'UserType': 1},
#                                      {'AccountIndex': 3,
#                                       'AccountIndexPad': '03',
#                                       'AccountType': 1,
#                                       'BrokerId': 4,
#                                       'BrokerName': 'FXCM福汇',
#                                       'UserType': 2},
#                                      {'AccountIndex': 4,
#                                       'AccountIndexPad': '04',
#                                       'AccountType': 2,
#                                       'BrokerId': 119,
#                                       'BrokerName': 'XM',
#                                       'UserType': 1}],
#                      'BizEndDate': '2018/12/26 06:00:19',
#                      'BizFollowAmount': '0.00',
#                      'BizFollowVolume': '0.00',
#                      'BizOneDayProfit': '0.00',
#                      'BizProfit': '0.00',
#                      'BizStartDate': '2018/12/25 22:54:38',
#                      'BizStrategyType': '固定数量',
#                      'BizWeeks': 1,
#                      'Chart': [],
#                      'CustomerNickName': '我是传奇',
#                      'CustomerUserId': 103696,
#                      'Direction': 1,
#                      'EndDate': '2018-12-26 06:00:19',
#                      'FollowBrokerID': 4,
#                      'FollowList': [],
#                      'FollowSetting': '0.01',
#                      'LastFollow': '',
#                      'MaxProfit': 0,
#                      'MinProfit': 0,
#                      'Profit': 0,
#                      'StandardLots': 0,
#                      'StartDate': '2018-12-25 22:54:38',
#                      'StrategyType': 1,
#                      'TotalDays': 1,
#                      'TotalTrades': 0,
#                      'TraderList': [{'Date': '1545667200',
#                                      'FollowMoney': 0,
#                                      'Money': 11.469999999999999,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 11205.999999999996,
#                                      'TotalPips': 16081.099999999997,
#                                      'TotalSelfMoney': 11205.999999999996,
#                                      'TotalSelfPips': 16081.099999999997,
#                                      'TotalSelfStandardlots': 90.92000000000003,
#                                      'TotalStandardlots': 90.92000000000003},
#                                     {'Date': '1545753600',
#                                      'FollowMoney': 0,
#                                      'Money': 58.100000000000016,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 11264.099999999997,
#                                      'TotalPips': 16258.199999999997,
#                                      'TotalSelfMoney': 11264.099999999997,
#                                      'TotalSelfPips': 16258.199999999997,
#                                      'TotalSelfStandardlots': 91.56000000000003,
#                                      'TotalStandardlots': 91.56000000000003}]},
#                     {'AccountCurrentIndex': 5,
#                      'AccountCurrentIndexPad': '05',
#                      'AccountList': [{'AccountIndex': 1,
#                                       'AccountIndexPad': '01',
#                                       'AccountType': 0,
#                                       'BrokerId': 3,
#                                       'BrokerName': '模拟账户',
#                                       'UserType': 0},
#                                      {'AccountIndex': 2,
#                                       'AccountIndexPad': '02',
#                                       'AccountType': 1,
#                                       'BrokerId': 6,
#                                       'BrokerName': 'KVB昆仑国际',
#                                       'UserType': 1},
#                                      {'AccountIndex': 3,
#                                       'AccountIndexPad': '03',
#                                       'AccountType': 1,
#                                       'BrokerId': 6,
#                                       'BrokerName': 'KVB昆仑国际',
#                                       'UserType': 2},
#                                      {'AccountIndex': 4,
#                                       'AccountIndexPad': '04',
#                                       'AccountType': 1,
#                                       'BrokerId': 4,
#                                       'BrokerName': 'FXCM福汇',
#                                       'UserType': 1},
#                                      {'AccountIndex': 5,
#                                       'AccountIndexPad': '05',
#                                       'AccountType': 1,
#                                       'BrokerId': 7,
#                                       'BrokerName': 'FxPro浦汇',
#                                       'UserType': 2},
#                                      {'AccountIndex': 6,
#                                       'AccountIndexPad': '06',
#                                       'AccountType': 1,
#                                       'BrokerId': 4,
#                                       'BrokerName': 'FXCM福汇',
#                                       'UserType': 2},
#                                      {'AccountIndex': 7,
#                                       'AccountIndexPad': '07',
#                                       'AccountType': 1,
#                                       'BrokerId': 7,
#                                       'BrokerName': 'FxPro浦汇',
#                                       'UserType': 2},
#                                      {'AccountIndex': 8,
#                                       'AccountIndexPad': '08',
#                                       'AccountType': 1,
#                                       'BrokerId': 4,
#                                       'BrokerName': 'FXCM福汇',
#                                       'UserType': 1}],
#                      'BizEndDate': '2018/12/29 12:23:26',
#                      'BizFollowAmount': '100.56',
#                      'BizFollowVolume': '0.00',
#                      'BizOneDayProfit': '0.00',
#                      'BizProfit': '0.00',
#                      'BizStartDate': '2018/12/28 11:14:31',
#                      'BizStrategyType': '固定数量',
#                      'BizWeeks': 1,
#                      'Chart': [],
#                      'CustomerNickName': '刘希达',
#                      'CustomerUserId': 216356,
#                      'Direction': 1,
#                      'EndDate': '2018-12-29 12:23:26',
#                      'FollowBrokerID': 7,
#                      'FollowList': [],
#                      'FollowSetting': '0.01',
#                      'LastFollow': '',
#                      'MaxProfit': 0,
#                      'MinProfit': 0,
#                      'Profit': 0,
#                      'StandardLots': 0,
#                      'StartDate': '2018-12-28 11:14:31',
#                      'StrategyType': 1,
#                      'TotalDays': 1,
#                      'TotalTrades': 0,
#                      'TraderList': [{'Date': '1545926400',
#                                      'FollowMoney': 0,
#                                      'Money': 90.66999999999997,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 11473.869999999997,
#                                      'TotalPips': 17263.099999999995,
#                                      'TotalSelfMoney': 11473.869999999997,
#                                      'TotalSelfPips': 17263.099999999995,
#                                      'TotalSelfStandardlots': 93.39000000000003,
#                                      'TotalStandardlots': 93.39000000000003},
#                                     {'Date': '1546012800',
#                                      'FollowMoney': 0,
#                                      'Money': 7.9,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 11481.769999999997,
#                                      'TotalPips': 17319.799999999996,
#                                      'TotalSelfMoney': 11481.769999999997,
#                                      'TotalSelfPips': 17319.799999999996,
#                                      'TotalSelfStandardlots': 93.43000000000004,
#                                      'TotalStandardlots': 93.43000000000004}]},
#                     {'AccountCurrentIndex': 1,
#                      'AccountCurrentIndexPad': '01',
#                      'AccountList': [{'AccountIndex': 1,
#                                       'AccountIndexPad': '01',
#                                       'AccountType': 0,
#                                       'BrokerId': 3,
#                                       'BrokerName': '模拟账户',
#                                       'UserType': 0}],
#                      'BizEndDate': '2018/12/26 07:00:45',
#                      'BizFollowAmount': '10,002.08',
#                      'BizFollowVolume': '0.00',
#                      'BizOneDayProfit': '0.00',
#                      'BizProfit': '0.00',
#                      'BizStartDate': '2018/12/26 06:59:44',
#                      'BizStrategyType': '固定数量',
#                      'BizWeeks': 1,
#                      'Chart': [],
#                      'CustomerNickName': '眉毛舞者',
#                      'CustomerUserId': 231594,
#                      'Direction': 1,
#                      'EndDate': '2018-12-26 07:00:45',
#                      'FollowBrokerID': 3,
#                      'FollowList': [],
#                      'FollowSetting': '0.01',
#                      'LastFollow': '',
#                      'MaxProfit': 0,
#                      'MinProfit': 0,
#                      'Profit': 0,
#                      'StandardLots': 0,
#                      'StartDate': '2018-12-26 06:59:44',
#                      'StrategyType': 1,
#                      'TotalDays': 0,
#                      'TotalTrades': 0,
#                      'TraderList': [{'Date': '1545753600',
#                                      'FollowMoney': 0,
#                                      'Money': 58.100000000000016,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 11264.099999999997,
#                                      'TotalPips': 16258.199999999997,
#                                      'TotalSelfMoney': 11264.099999999997,
#                                      'TotalSelfPips': 16258.199999999997,
#                                      'TotalSelfStandardlots': 91.56000000000003,
#                                      'TotalStandardlots': 91.56000000000003}]},
#                     {'AccountCurrentIndex': 1,
#                      'AccountCurrentIndexPad': '01',
#                      'AccountList': [{'AccountIndex': 1,
#                                       'AccountIndexPad': '01',
#                                       'AccountType': 0,
#                                       'BrokerId': 3,
#                                       'BrokerName': '模拟账户',
#                                       'UserType': 0}],
#                      'BizEndDate': '2018/12/28 17:56:54',
#                      'BizFollowAmount': '9,958.46',
#                      'BizFollowVolume': '0.00',
#                      'BizOneDayProfit': '0.00',
#                      'BizProfit': '0.00',
#                      'BizStartDate': '2018/12/28 15:37:05',
#                      'BizStrategyType': '按比例',
#                      'BizWeeks': 1,
#                      'Chart': [],
#                      'CustomerNickName': '天意金',
#                      'CustomerUserId': 231960,
#                      'Direction': 1,
#                      'EndDate': '2018-12-28 17:56:54',
#                      'FollowBrokerID': 3,
#                      'FollowList': [],
#                      'FollowSetting': '0.1',
#                      'LastFollow': '',
#                      'MaxProfit': 0,
#                      'MinProfit': 0,
#                      'Profit': 0,
#                      'StandardLots': 0,
#                      'StartDate': '2018-12-28 15:37:05',
#                      'StrategyType': 2,
#                      'TotalDays': 0,
#                      'TotalTrades': 0,
#                      'TraderList': [{'Date': '1545926400',
#                                      'FollowMoney': 0,
#                                      'Money': 90.66999999999997,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 11473.869999999997,
#                                      'TotalPips': 17263.099999999995,
#                                      'TotalSelfMoney': 11473.869999999997,
#                                      'TotalSelfPips': 17263.099999999995,
#                                      'TotalSelfStandardlots': 93.39000000000003,
#                                      'TotalStandardlots': 93.39000000000003}]},
#                     {'AccountCurrentIndex': 1,
#                      'AccountCurrentIndexPad': '01',
#                      'AccountList': [{'AccountIndex': 1,
#                                       'AccountIndexPad': '01',
#                                       'AccountType': 0,
#                                       'BrokerId': 3,
#                                       'BrokerName': '模拟账户',
#                                       'UserType': 0}],
#                      'BizEndDate': '2018/12/29 10:54:17',
#                      'BizFollowAmount': '10,017.48',
#                      'BizFollowVolume': '0.00',
#                      'BizOneDayProfit': '0.00',
#                      'BizProfit': '0.00',
#                      'BizStartDate': '2018/12/29 10:29:24',
#                      'BizStrategyType': '固定数量',
#                      'BizWeeks': 1,
#                      'Chart': [],
#                      'CustomerNickName': '立讯精密思琪研指',
#                      'CustomerUserId': 232178,
#                      'Direction': 1,
#                      'EndDate': '2018-12-29 10:54:17',
#                      'FollowBrokerID': 3,
#                      'FollowList': [],
#                      'FollowSetting': '0.01',
#                      'LastFollow': '',
#                      'MaxProfit': 0,
#                      'MinProfit': 0,
#                      'Profit': 0,
#                      'StandardLots': 0,
#                      'StartDate': '2018-12-29 10:29:24',
#                      'StrategyType': 1,
#                      'TotalDays': 0,
#                      'TotalTrades': 0,
#                      'TraderList': [{'Date': '1546012800',
#                                      'FollowMoney': 0,
#                                      'Money': 7.9,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 11481.769999999997,
#                                      'TotalPips': 17319.799999999996,
#                                      'TotalSelfMoney': 11481.769999999997,
#                                      'TotalSelfPips': 17319.799999999996,
#                                      'TotalSelfStandardlots': 93.43000000000004,
#                                      'TotalStandardlots': 93.43000000000004}]},
#                     {'AccountCurrentIndex': 2,
#                      'AccountCurrentIndexPad': '02',
#                      'AccountList': [{'AccountIndex': 1,
#                                       'AccountIndexPad': '01',
#                                       'AccountType': 0,
#                                       'BrokerId': 3,
#                                       'BrokerName': '模拟账户',
#                                       'UserType': 0},
#                                      {'AccountIndex': 2,
#                                       'AccountIndexPad': '02',
#                                       'AccountType': 2,
#                                       'BrokerId': 119,
#                                       'BrokerName': 'XM',
#                                       'UserType': 2}],
#                      'BizEndDate': '2018/12/25 13:11:50',
#                      'BizFollowAmount': '165.41',
#                      'BizFollowVolume': '0.00',
#                      'BizOneDayProfit': '0.00',
#                      'BizProfit': '0.00',
#                      'BizStartDate': '2018/12/25 13:11:17',
#                      'BizStrategyType': '固定数量',
#                      'BizWeeks': 1,
#                      'Chart': [],
#                      'CustomerNickName': '龙马嘿',
#                      'CustomerUserId': 231295,
#                      'Direction': 1,
#                      'EndDate': '2018-12-25 13:11:50',
#                      'FollowBrokerID': 119,
#                      'FollowList': [],
#                      'FollowSetting': '0.01',
#                      'LastFollow': '',
#                      'MaxProfit': 0,
#                      'MinProfit': 0,
#                      'Profit': 0,
#                      'StandardLots': 0,
#                      'StartDate': '2018-12-25 13:11:17',
#                      'StrategyType': 1,
#                      'TotalDays': 0,
#                      'TotalTrades': 0,
#                      'TraderList': [{'Date': '1545667200',
#                                      'FollowMoney': 0,
#                                      'Money': 11.469999999999999,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 11205.999999999996,
#                                      'TotalPips': 16081.099999999997,
#                                      'TotalSelfMoney': 11205.999999999996,
#                                      'TotalSelfPips': 16081.099999999997,
# ...
#                                      'TotalPips': 17319.799999999996,
#                                      'TotalSelfMoney': 11481.769999999997,
#                                      'TotalSelfPips': 17319.799999999996,
#                                      'TotalSelfStandardlots': 93.43000000000004,
#                                      'TotalStandardlots': 93.43000000000004},
#                                     {'Date': '1546185600',
#                                      'FollowMoney': 0,
#                                      'Money': 69.43999999999998,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 11551.209999999997,
#                                      'TotalPips': 17350.399999999994,
#                                      'TotalSelfMoney': 11551.209999999997,
#                                      'TotalSelfPips': 17350.399999999994,
#                                      'TotalSelfStandardlots': 94.24000000000004,
#                                      'TotalStandardlots': 94.24000000000004}]},
#                     {'AccountCurrentIndex': 1,
#                      'AccountCurrentIndexPad': '01',
#                      'AccountList': [{'AccountIndex': 1,
#                                       'AccountIndexPad': '01',
#                                       'AccountType': 0,
#                                       'BrokerId': 3,
#                                       'BrokerName': '模拟账户',
#                                       'UserType': 0}],
#                      'BizEndDate': '2018/12/31 17:21:09',
#                      'BizFollowAmount': '9,590.77',
#                      'BizFollowVolume': '0.00',
#                      'BizOneDayProfit': '0.00',
#                      'BizProfit': '-6.14',
#                      'BizStartDate': '2018/12/31 11:01:28',
#                      'BizStrategyType': '固定数量',
#                      'BizWeeks': 1,
#                      'Chart': [{'Date': 20181231,
#                                 'FollowerTotalProfit': -6.14,
#                                 'TraderTotalProfit': 69.44}],
#                      'CustomerNickName': 'shuisebitian',
#                      'CustomerUserId': 232186,
#                      'Direction': 1,
#                      'EndDate': '2018-12-31 17:21:09',
#                      'FollowBrokerID': 3,
#                      'FollowList': [],
#                      'FollowSetting': '0.01',
#                      'LastFollow': '',
#                      'MaxProfit': 3.18,
#                      'MinProfit': -3.89,
#                      'Profit': -6.140000000000001,
#                      'StandardLots': 0.07,
#                      'StartDate': '2018-12-31 11:01:28',
#                      'StrategyType': 1,
#                      'TotalDays': 0,
#                      'TotalTrades': 7,
#                      'TraderList': [{'Date': '1546185600',
#                                      'FollowMoney': 0,
#                                      'Money': 69.43999999999998,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 11551.209999999997,
#                                      'TotalPips': 17350.399999999994,
#                                      'TotalSelfMoney': 11551.209999999997,
#                                      'TotalSelfPips': 17350.399999999994,
#                                      'TotalSelfStandardlots': 94.24000000000004,
#                                      'TotalStandardlots': 94.24000000000004}]},
#                     {'AccountCurrentIndex': 2,
#                      'AccountCurrentIndexPad': '02',
#                      'AccountList': [{'AccountIndex': 1,
#                                       'AccountIndexPad': '01',
#                                       'AccountType': 0,
#                                       'BrokerId': 3,
#                                       'BrokerName': '模拟账户',
#                                       'UserType': 0},
#                                      {'AccountIndex': 2,
#                                       'AccountIndexPad': '02',
#                                       'AccountType': 2,
#                                       'BrokerId': 102,
#                                       'BrokerName': 'Ava爱华',
#                                       'UserType': 2}],
#                      'BizEndDate': '2018/12/31 20:56:30',
#                      'BizFollowAmount': '205.32',
#                      'BizFollowVolume': '0.00',
#                      'BizOneDayProfit': '0.00',
#                      'BizProfit': '-7.85',
#                      'BizStartDate': '2018/12/27 19:45:43',
#                      'BizStrategyType': '按比例',
#                      'BizWeeks': 1,
#                      'Chart': [{'Date': 20181227,
#                                 'FollowerTotalProfit': 19.65,
#                                 'TraderTotalProfit': 119.1},
#                                {'Date': 20181228,
#                                 'FollowerTotalProfit': 22.93,
#                                 'TraderTotalProfit': 209.77},
#                                {'Date': 20181230,
#                                 'FollowerTotalProfit': 23.23,
#                                 'TraderTotalProfit': 209.77},
#                                {'Date': 20181231,
#                                 'FollowerTotalProfit': -7.85,
#                                 'TraderTotalProfit': 279.21}],
#                      'CustomerNickName': '2735',
#                      'CustomerUserId': 213198,
#                      'Direction': 1,
#                      'EndDate': '2018-12-31 20:56:30',
#                      'FollowBrokerID': 102,
#                      'FollowList': [{'Date': '1545926400',
#                                      'FollowMoney': 3.2000000000000015,
#                                      'Money': 3.2800000000000016,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 3.2800000000000016,
#                                      'TotalPips': 0,
#                                      'TotalSelfMoney': 0,
#                                      'TotalSelfPips': 0,
#                                      'TotalSelfStandardlots': 0,
#                                      'TotalStandardlots': 0},
#                                     {'Date': '1546099200',
#                                      'FollowMoney': 0.29999999999999993,
#                                      'Money': 0.29999999999999993,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 3.5800000000000014,
#                                      'TotalPips': 0,
#                                      'TotalSelfMoney': 0,
#                                      'TotalSelfPips': 0,
#                                      'TotalSelfStandardlots': 0,
#                                      'TotalStandardlots': 0}],
#                      'FollowSetting': '1',
#                      'LastFollow': '',
#                      'MaxProfit': 10.040000000000001,
#                      'MinProfit': -14.14,
#                      'Profit': -7.8499999999999925,
#                      'StandardLots': 0.7900000000000005,
#                      'StartDate': '2018-12-27 19:45:43',
#                      'StrategyType': 2,
#                      'TotalDays': 4,
#                      'TotalTrades': 53,
#                      'TraderList': [{'Date': '1545840000',
#                                      'FollowMoney': 0,
#                                      'Money': 119.09999999999997,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 11383.199999999997,
#                                      'TotalPips': 16715.799999999996,
#                                      'TotalSelfMoney': 11383.199999999997,
#                                      'TotalSelfPips': 16715.799999999996,
#                                      'TotalSelfStandardlots': 92.64000000000003,
#                                      'TotalStandardlots': 92.64000000000003},
#                                     {'Date': '1545926400',
#                                      'FollowMoney': 0,
#                                      'Money': 90.66999999999997,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 11473.869999999997,
#                                      'TotalPips': 17263.099999999995,
#                                      'TotalSelfMoney': 11473.869999999997,
#                                      'TotalSelfPips': 17263.099999999995,
#                                      'TotalSelfStandardlots': 93.39000000000003,
#                                      'TotalStandardlots': 93.39000000000003},
#                                     {'Date': '1546012800',
#                                      'FollowMoney': 0,
#                                      'Money': 7.9,
#                                      'TotalFollowMoney': 0,
#                                      'TotalFollowPips': 0,
#                                      'TotalFollowStandardlots': 0,
#                                      'TotalMoney': 